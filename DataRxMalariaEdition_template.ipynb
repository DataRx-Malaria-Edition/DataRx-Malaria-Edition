# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = pd.read_excel('Malaria_Research_Data.xlsx', header=0)
total_spectra = data.groupby('Biological sample category')['Protein percentage of total spectra'].sum()

# Normalize the protein percentages within each group
data['Normalized protein percentage'] = data.groupby('Biological sample category')['Protein percentage of total spectra'].transform(lambda x: (x / x.sum()) * 100)

print(data)
# Out:
#                                   Experiment name Biological sample category
# 0        SPP vs. NAT coIP results recieved 1.9.23                        NAT  \
# 1        SPP vs. NAT coIP results recieved 1.9.23                        NAT
# 2        SPP vs. NAT coIP results recieved 1.9.23                        NAT
# 3        SPP vs. NAT coIP results recieved 1.9.23                        NAT
# 4        SPP vs. NAT coIP results recieved 1.9.23                        NAT
# ...                                           ...                        ...
# 19259  SPP vs. NAT coIP results recieved 11.15.22                        SPP
# 19260  SPP vs. NAT coIP results recieved 11.15.22                        SPP
# 19261  SPP vs. NAT coIP results recieved 11.15.22                        SPP
# 19262  SPP vs. NAT coIP results recieved 11.15.22                        SPP
# 19263  SPP vs. NAT coIP results recieved 11.15.22                        SPP
#
#                                            Protein group
# 0      DNA helicase OS=Plasmodium falciparum (isolate...  \
# 1      DNA helicase OS=Plasmodium falciparum (isolate...
# 2      DNA helicase OS=Plasmodium falciparum (isolate...
# 3      Merozoite surface protein 9 OS=Plasmodium falc...
# 4      Merozoite surface protein 9 OS=Plasmodium falc...
# ...                                                  ...
# 19259  Pyruvate kinase OS=Plasmodium falciparum (isol...
# 19260  Golgi protein 2 OS=Plasmodium falciparum (isol...
# 19261  Golgi protein 2 OS=Plasmodium falciparum (isol...
# 19262  Golgi protein 2 OS=Plasmodium falciparum (isol...
# 19263  Golgi protein 2 OS=Plasmodium falciparum (isol...
#
#       Protein accession number
# 0                       Q8IEE5  \
# 1                       Q8IEE5
# 2                       Q8IEE5
# 3                   A0A144A026
# 4                   A0A144A026
# ...                        ...
# 19259                   Q8IJ37
# 19260                   Q8IIC8
# 19261                   Q8IIC8
# 19262                   Q8IIC8
# 19263                   Q8IIC8
#
#                                             Protein name
# 0      DNA helicase OS=Plasmodium falciparum (isolate...  \
# 1      DNA helicase OS=Plasmodium falciparum (isolate...
# 2      DNA helicase OS=Plasmodium falciparum (isolate...
# 3      Merozoite surface protein 9 OS=Plasmodium falc...
# 4      Merozoite surface protein 9 OS=Plasmodium falc...
# ...                                                  ...
# 19259  Pyruvate kinase OS=Plasmodium falciparum (isol...
# 19260  Golgi protein 2 OS=Plasmodium falciparum (isol...
# 19261  Golgi protein 2 OS=Plasmodium falciparum (isol...
# 19262  Golgi protein 2 OS=Plasmodium falciparum (isol...
# 19263  Golgi protein 2 OS=Plasmodium falciparum (isol...
#
#        Protein identification probability
# 0                                     1.0  \
# 1                                     1.0
# 2                                     1.0
# 3                                     1.0
# 4                                     1.0
# ...                                   ...
# 19259                                 1.0
# 19260                                 1.0
# 19261                                 1.0
# 19262                                 1.0
# 19263                                 1.0
#
#        Protein percentage of total spectra  Number of unique peptides
# 0                                 0.000016                          3  \
# 1                                 0.000016                          3
# 2                                 0.000016                          3
# 3                                 0.000016                          3
# 4                                 0.000016                          3
# ...                                    ...                        ...
# 19259                             0.000015                          2
# 19260                             0.000020                          3
# 19261                             0.000020                          3
# 19262                             0.000020                          3
# 19263                             0.000020                          3
#
#        Number of unique spectra  Number of total spectra
# 0                             3                        3  \
# 1                             3                        3
# 2                             3                        3
# 3                             3                        3
# 4                             3                        3
# ...                         ...                      ...
# 19259                         2                        3
# 19260                         3                        4
# 19261                         3                        4
# 19262                         3                        4
# 19263                         3                        4
#
#            Peptide sequence Previous amino acid Next amino acid
# 0            EYILESGAVVLSDK                   K               G  \
# 1         LMNIATFQSLIDPLSGR                   R               I
# 2      LNNTNYEDDDENNENSEGIR                   R               N
# 3                  ENVDYIQK                   K               N
# 4          KAPSDPQCADIKEECK                   K               E
# ...                     ...                 ...             ...
# 19259            LYLNGIDVFR                   K               L
# 19260          ILNDIINEDDIK                   K               T
# 19261        NESFLLPLPPLTTK                   K               S
# 19262            VVNPNFYYDR                   K               A
# 19263            VVNPNFYYDR                   K               A
#
#        Peptide identification probability
# 0                                   0.921  \
# 1                                   0.997
# 2                                   0.981
# 3                                   0.990
# 4                                   0.994
# ...                                   ...
# 19259                               0.993
# 19260                               0.997
# 19261                               0.950
# 19262                               0.979
# 19263                               0.997
#
#                Modifications identified by spectrum  Peptide start index
# 0                                               NaN                  611  \
# 1                                               NaN                  903
# 2                                               NaN                  187
# 3                                               NaN                  167
# 4      Carbamidomethyl (+57), Carbamidomethyl (+57)                   62
# ...                                             ...                  ...
# 19259                               Deamidated (+1)                    2
# 19260                                           NaN                    2
# 19261                                           NaN                    2
# 19262                                           NaN                    2
# 19263                                           NaN                    2
#
#        Peptide stop index  Unnamed: 17  Normalized protein percentage
# 0                     624          NaN                       0.001008
# 1                     919          NaN                       0.001008
# 2                     206          NaN                       0.001008
# 3                     174          NaN                       0.001008
# 4                      77          NaN                       0.001008
# ...                   ...          ...                            ...
# 19259                 118        127.0                       0.001111
# 19260                 526        537.0                       0.001481
# 19261                 690        703.0                       0.001481
# 19262                1004       1013.0                       0.001481
# 19263                1004       1013.0                       0.001481
#
# [19264 rows x 19 columns]

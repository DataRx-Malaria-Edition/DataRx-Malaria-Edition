# %% [markdown]
# ### Research question 5: Are transmembrane domains enriched in the SPP vs. NAT peptides?
#
# #### Transmembrane domains
#
# * Transmembrane domains are portions of the enzyme which are embedded within a cell membrane or organelle membrane
# * In the case of SPP, the membrane in question is attached to the rough endoplasmic reticulum (ER) allowing for cleaving of signal peptides
# * As per the previous questions, the intent is to compare SPP is against NAT in terms of the individual peptide sequences which cross the membranes to determine which (if any) are more prevalent in SPP
#
# #### Overall Method of solution
# The provided data-set includes peptide sequences which are to be analyzed using non-local processing, the results of this are then to be recorded and then compared.
#
# #### Purpose of this code segment
# To generate FASTA files from the source .xlsx and send the data off for TMHMM processing while recording the results.
#
# #### Method of solution
#
# * Import pybiolib
#   * A common biotech library allowing for TMHMM analysis
#   * Returns values giving the probability of where the peptide sequence will be found in reference to a membrane
# *  Importing lab data from .xlsx
# *  Creation of files fitting the FASTA format in preparation for processing
#   * FASTA format
#     * .txt file
#     * Documentation/general identification on the first line
#     * Peptide sequence on the following line to be read
# * Send each individual file for TMHMM processing
#   * Full data set of 20000 requires about 100 hours of processing time
# * Record results in a local directory "transmembrane_local_directory"
#   * Each data collection is recorded in a subdirectory noting the record ranges
#   * Each record is in its own subdirectory corresponding to the record number
#
# NOTE: Since the data set is too large to process all at once, data analysis must be done several hundred records at a time. The provided code includes globals which can be changed to vary which records to process.

# %%
# !pip3 install -qU pybiolib
import biolib
import pandas as pd
import os
import re
deeptmhmm = biolib.load('DTU/DeepTMHMM')
biolib.login()
# Out:
# 2023-06-06 17:52:59,023 | INFO : Loaded project DTU/DeepTMHMM:1.0.24
# 2023-06-06 17:52:59,025 | INFO : Already signed in

# %%
import re
import os
deeptmhmm = biolib.load('DTU/DeepTMHMM')
biolib.utils.STREAM_STDOUT = True
accession_only = True

# Modify this as needed to collect new data sets from TMHMM
start_index = 1200
end_index = 2000

def make_file(file_name, pep_seq):
    with open(file_name, "w") as file:
        sample_category = pep_seq['Biological sample category']
        protein_name = pep_seq['Protein name']
        normalized_percent = pep_seq['Normalized protein percentage']
        peptide_sequence = pep_seq['Peptide sequence']
        accession_number = pep_seq['Protein accession number']
        
        pattern = r"OX=\d+"
        match = re.search(pattern, protein_name)

        pattern2 = r"GN=\w+"
        match2 = re.search(pattern2, protein_name)

        if not accession_only and match and match2:
            ox_value = match.group()
            gn_value = match2.group()
            oxgn_value = str(ox_value) + " " + str(gn_value)
        else:
            oxgn_value = str(accession_number)            
        
        header = ">Type: " + str(sample_category) + " ||| " + oxgn_value + " ||| " + str(normalized_percent) + "\n"
        file.write(header)
        file.write(peptide_sequence)


# Only a certain number of records can be analyzed at a given time
data = pd.read_excel('output.xlsx', header=0)

data = data.iloc[start_index:end_index]

directory = 'transmembrane_local_directory/transmembrane_results_local_'+str(start_index)+'_'+str(end_index-1)
os.makedirs(directory)


fasta_list = []

# Generate fasta format files for deepTMHMM processing
for index, peptide in data.iterrows():
    
    make_file("fasta_files/query"+str(index)+".fasta", peptide)
    fasta_list.append("fasta_files/query"+str(index)+".fasta")

print("List writing complete")

# Send the fasta files to the TMHMM database for processing and save the results
index = start_index
with biolib.Experiment('TMHMM_analysis'):
    for fasta_file in fasta_list:
        result = deeptmhmm.cli(args='--fasta '+fasta_file, machine='local')
        result.save_files(directory+'/peptide_row'+str(index))
        index+=1

print("done!")
# Out:
# 2023-06-07 14:05:22,747 | INFO : Loaded project DTU/DeepTMHMM:1.0.24
# List writing complete
# 2023-06-07 14:05:27,687 | INFO : Job "272f9499-583f-45c1-947c-00016c36727f" is starting...
# 2023-06-07 14:05:27,993 | INFO : Started compute node
# 2023-06-07 14:05:28,702 | INFO : Compute Node: Initializing
# 2023-06-07 14:05:29,145 | INFO : Job "272f9499-583f-45c1-947c-00016c36727f" running...
# 2023-06-07 14:05:30,205 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:05:30,205 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  3.70seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  8.32seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:05:39,227 | INFO : Compute Node: Computation finished
# 2023-06-07 14:05:39,228 | INFO : Compute Node: Result Ready
# 2023-06-07 14:05:39,825 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1200...
# 2023-06-07 14:05:39,826 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1200/TMRs.gff3
# 2023-06-07 14:05:39,826 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1200/plot.png
# 2023-06-07 14:05:39,827 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1200/predicted_topologies.3line
# 2023-06-07 14:05:39,828 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1200/deeptmhmm_results.md
# 2023-06-07 14:05:39,829 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1200/Type:_probs.csv
# 2023-06-07 14:05:41,202 | INFO : Job "c4604d28-f885-46ac-9e46-38cf85afae4e" is starting...
# 2023-06-07 14:05:41,494 | INFO : Started compute node
# 2023-06-07 14:05:42,217 | INFO : Compute Node: Initializing
# 2023-06-07 14:05:42,646 | INFO : Job "c4604d28-f885-46ac-9e46-38cf85afae4e" running...
# 2023-06-07 14:05:43,720 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:05:43,721 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.84seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  6.30seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:05:52,742 | INFO : Compute Node: Computation finished
# 2023-06-07 14:05:52,742 | INFO : Compute Node: Result Ready
# 2023-06-07 14:05:53,355 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1201...
# 2023-06-07 14:05:53,356 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1201/TMRs.gff3
# 2023-06-07 14:05:53,357 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1201/plot.png
# 2023-06-07 14:05:53,358 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1201/predicted_topologies.3line
# 2023-06-07 14:05:53,359 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1201/deeptmhmm_results.md
# 2023-06-07 14:05:53,360 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1201/Type:_probs.csv
# 2023-06-07 14:05:54,700 | INFO : Job "c041827b-1424-4d6d-a025-a364fdee5cfa" is starting...
# 2023-06-07 14:05:54,998 | INFO : Started compute node
# 2023-06-07 14:05:55,722 | INFO : Compute Node: Initializing
# 2023-06-07 14:05:56,205 | INFO : Job "c041827b-1424-4d6d-a025-a364fdee5cfa" running...
# 2023-06-07 14:05:57,226 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:05:57,226 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.77seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  7.25seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:06:06,248 | INFO : Compute Node: Computation finished
# 2023-06-07 14:06:06,249 | INFO : Compute Node: Result Ready
# 2023-06-07 14:06:06,900 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1202...
# 2023-06-07 14:06:06,901 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1202/TMRs.gff3
# 2023-06-07 14:06:06,902 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1202/plot.png
# 2023-06-07 14:06:06,903 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1202/predicted_topologies.3line
# 2023-06-07 14:06:06,904 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1202/deeptmhmm_results.md
# 2023-06-07 14:06:06,904 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1202/Type:_probs.csv
# 2023-06-07 14:06:08,263 | INFO : Job "8aa28771-e942-4571-91ec-c26c678b5d08" is starting...
# 2023-06-07 14:06:08,743 | INFO : Started compute node
# 2023-06-07 14:06:09,279 | INFO : Compute Node: Initializing
# 2023-06-07 14:06:09,716 | INFO : Job "8aa28771-e942-4571-91ec-c26c678b5d08" running...
# 2023-06-07 14:06:10,783 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:06:10,784 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.78seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  4.27seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:06:19,805 | INFO : Compute Node: Computation finished
# 2023-06-07 14:06:19,806 | INFO : Compute Node: Result Ready
# 2023-06-07 14:06:19,815 | ERROR : Failed to clean up <Network: 22bb0a4fcb63>
# 2023-06-07 14:06:19,816 | ERROR : 404 Client Error for http+docker://localhost/v1.41/networks/22bb0a4fcb632da6eb1e6de06bf15050fd3307a1c895247185561a344af4b486: Not Found ("network 22bb0a4fcb632da6eb1e6de06bf15050fd3307a1c895247185561a344af4b486 not found")
# 2023-06-07 14:06:20,440 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1203...
# 2023-06-07 14:06:20,442 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1203/TMRs.gff3
# 2023-06-07 14:06:20,442 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1203/plot.png
# 2023-06-07 14:06:20,443 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1203/predicted_topologies.3line
# 2023-06-07 14:06:20,443 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1203/deeptmhmm_results.md
# 2023-06-07 14:06:20,444 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1203/Type:_probs.csv
# 2023-06-07 14:06:21,882 | INFO : Job "2fecded0-66ed-45d3-b408-aa2d72c0d8ad" is starting...
# 2023-06-07 14:06:22,294 | INFO : Started compute node
# 2023-06-07 14:06:22,899 | INFO : Compute Node: Initializing
# 2023-06-07 14:06:23,296 | INFO : Job "2fecded0-66ed-45d3-b408-aa2d72c0d8ad" running...
# 2023-06-07 14:06:24,403 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:06:24,404 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.32seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  6.80seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:06:33,429 | INFO : Compute Node: Computation finished
# 2023-06-07 14:06:33,430 | INFO : Compute Node: Result Ready
# 2023-06-07 14:06:34,225 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1204...
# 2023-06-07 14:06:34,226 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1204/TMRs.gff3
# 2023-06-07 14:06:34,227 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1204/plot.png
# 2023-06-07 14:06:34,228 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1204/predicted_topologies.3line
# 2023-06-07 14:06:34,228 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1204/deeptmhmm_results.md
# 2023-06-07 14:06:34,229 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1204/Type:_probs.csv
# 2023-06-07 14:06:35,619 | INFO : Job "53a80517-b25d-4848-a9f0-5d5d6d94fdc4" is starting...
# 2023-06-07 14:06:35,965 | INFO : Started compute node
# 2023-06-07 14:06:36,638 | INFO : Compute Node: Initializing
# 2023-06-07 14:06:37,315 | INFO : Job "53a80517-b25d-4848-a9f0-5d5d6d94fdc4" running...
# 2023-06-07 14:06:38,142 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:06:38,142 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.05seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  3.63seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:06:47,165 | INFO : Compute Node: Computation finished
# 2023-06-07 14:06:47,166 | INFO : Compute Node: Result Ready
# 2023-06-07 14:06:47,803 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1205...
# 2023-06-07 14:06:47,804 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1205/TMRs.gff3
# 2023-06-07 14:06:47,805 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1205/plot.png
# 2023-06-07 14:06:47,806 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1205/predicted_topologies.3line
# 2023-06-07 14:06:47,807 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1205/deeptmhmm_results.md
# 2023-06-07 14:06:47,807 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1205/Type:_probs.csv
# 2023-06-07 14:06:49,181 | INFO : Job "d49de2c9-3020-4198-8114-34d23ce70682" is starting...
# 2023-06-07 14:06:49,597 | INFO : Started compute node
# 2023-06-07 14:06:50,197 | INFO : Compute Node: Initializing
# 2023-06-07 14:06:50,616 | INFO : Job "d49de2c9-3020-4198-8114-34d23ce70682" running...
# 2023-06-07 14:06:51,701 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:06:51,701 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  1.80seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  3.26seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:07:02,225 | INFO : Compute Node: Computation finished
# 2023-06-07 14:07:02,226 | INFO : Compute Node: Result Ready
# 2023-06-07 14:07:02,851 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1206...
# 2023-06-07 14:07:02,853 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1206/TMRs.gff3
# 2023-06-07 14:07:02,854 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1206/plot.png
# 2023-06-07 14:07:02,855 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1206/predicted_topologies.3line
# 2023-06-07 14:07:02,856 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1206/deeptmhmm_results.md
# 2023-06-07 14:07:02,857 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1206/Type:_probs.csv
# 2023-06-07 14:07:04,287 | INFO : Job "6d468a8e-22a7-49fa-b3ea-53264fbe152f" is starting...
# 2023-06-07 14:07:04,603 | INFO : Started compute node
# 2023-06-07 14:07:05,306 | INFO : Compute Node: Initializing
# 2023-06-07 14:07:05,856 | INFO : Job "6d468a8e-22a7-49fa-b3ea-53264fbe152f" running...
# 2023-06-07 14:07:06,810 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:07:06,811 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  1.35seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  3.24seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:07:17,335 | INFO : Compute Node: Computation finished
# 2023-06-07 14:07:17,337 | INFO : Compute Node: Result Ready
# 2023-06-07 14:07:17,958 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1207...
# 2023-06-07 14:07:17,959 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1207/TMRs.gff3
# 2023-06-07 14:07:17,960 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1207/plot.png
# 2023-06-07 14:07:17,960 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1207/predicted_topologies.3line
# 2023-06-07 14:07:17,961 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1207/deeptmhmm_results.md
# 2023-06-07 14:07:17,962 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1207/Type:_probs.csv
# 2023-06-07 14:07:19,335 | INFO : Job "ebfe0ddd-9521-4eeb-975f-c04a141e2c0f" is starting...
# 2023-06-07 14:07:19,640 | INFO : Started compute node
# 2023-06-07 14:07:20,351 | INFO : Compute Node: Initializing
# 2023-06-07 14:07:20,776 | INFO : Job "ebfe0ddd-9521-4eeb-975f-c04a141e2c0f" running...
# 2023-06-07 14:07:21,854 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:07:21,855 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  1.98seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  3.24seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:07:32,380 | INFO : Compute Node: Computation finished
# 2023-06-07 14:07:32,381 | INFO : Compute Node: Result Ready
# 2023-06-07 14:07:33,021 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1208...
# 2023-06-07 14:07:33,022 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1208/TMRs.gff3
# 2023-06-07 14:07:33,023 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1208/plot.png
# 2023-06-07 14:07:33,024 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1208/predicted_topologies.3line
# 2023-06-07 14:07:33,025 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1208/deeptmhmm_results.md
# 2023-06-07 14:07:33,025 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1208/Type:_probs.csv
# 2023-06-07 14:07:34,462 | INFO : Job "e41ee162-fe03-40fb-bb51-7a12766492ce" is starting...
# 2023-06-07 14:07:34,765 | INFO : Started compute node
# 2023-06-07 14:07:35,478 | INFO : Compute Node: Initializing
# 2023-06-07 14:07:36,147 | INFO : Job "e41ee162-fe03-40fb-bb51-7a12766492ce" running...
# 2023-06-07 14:07:36,981 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:07:36,982 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  1.93seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction:   0% 0/1 [00:00<?, ?seq/s]2023-06-07 14:07:46,005 | INFO : Compute Node: Computation finished
# Topology prediction: 100% 1/1 [00:00<00:00,  2.61seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:07:46,006 | INFO : Compute Node: Result Ready
# 2023-06-07 14:07:46,015 | ERROR : Failed to clean up <Network: d867b2bb11f4>
# 2023-06-07 14:07:46,015 | ERROR : 404 Client Error for http+docker://localhost/v1.41/networks/d867b2bb11f45e9204a8c92d19608076e99f262642566de572ee6850835ebc45: Not Found ("network d867b2bb11f45e9204a8c92d19608076e99f262642566de572ee6850835ebc45 not found")
# 2023-06-07 14:07:46,678 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1209...
# 2023-06-07 14:07:46,680 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1209/TMRs.gff3
# 2023-06-07 14:07:46,681 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1209/plot.png
# 2023-06-07 14:07:46,681 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1209/predicted_topologies.3line
# 2023-06-07 14:07:46,682 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1209/deeptmhmm_results.md
# 2023-06-07 14:07:46,683 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1209/Type:_probs.csv
# 2023-06-07 14:07:48,078 | INFO : Job "fb371077-24a1-4c5f-9a63-a3c73595cfef" is starting...
# 2023-06-07 14:07:48,379 | INFO : Started compute node
# 2023-06-07 14:07:49,094 | INFO : Compute Node: Initializing
# 2023-06-07 14:07:49,495 | INFO : Job "fb371077-24a1-4c5f-9a63-a3c73595cfef" running...
# 2023-06-07 14:07:50,597 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:07:50,598 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.21seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  5.38seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:07:59,619 | INFO : Compute Node: Computation finished
# 2023-06-07 14:07:59,620 | INFO : Compute Node: Result Ready
# 2023-06-07 14:07:59,631 | ERROR : Failed to clean up <Network: 59facbb1a1f4>
# 2023-06-07 14:07:59,631 | ERROR : 404 Client Error for http+docker://localhost/v1.41/networks/59facbb1a1f4b6d16d3b505751a135ff89c8f79a74d27cd5393883a5271cdf45: Not Found ("network 59facbb1a1f4b6d16d3b505751a135ff89c8f79a74d27cd5393883a5271cdf45 not found")
# 2023-06-07 14:08:00,226 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1210...
# 2023-06-07 14:08:00,227 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1210/TMRs.gff3
# 2023-06-07 14:08:00,228 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1210/plot.png
# 2023-06-07 14:08:00,228 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1210/predicted_topologies.3line
# 2023-06-07 14:08:00,229 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1210/deeptmhmm_results.md
# 2023-06-07 14:08:00,230 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1210/Type:_probs.csv
# 2023-06-07 14:08:01,594 | INFO : Job "8f839d1d-77ab-4d3e-83e9-36a234cecabc" is starting...
# 2023-06-07 14:08:01,953 | INFO : Started compute node
# 2023-06-07 14:08:02,610 | INFO : Compute Node: Initializing
# 2023-06-07 14:08:03,036 | INFO : Job "8f839d1d-77ab-4d3e-83e9-36a234cecabc" running...
# 2023-06-07 14:08:04,119 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:08:04,122 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.71seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  7.51seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:08:13,143 | INFO : Compute Node: Computation finished
# 2023-06-07 14:08:13,144 | INFO : Compute Node: Result Ready
# 2023-06-07 14:08:13,756 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1211...
# 2023-06-07 14:08:13,757 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1211/TMRs.gff3
# 2023-06-07 14:08:13,758 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1211/plot.png
# 2023-06-07 14:08:13,759 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1211/predicted_topologies.3line
# 2023-06-07 14:08:13,759 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1211/deeptmhmm_results.md
# 2023-06-07 14:08:13,760 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1211/Type:_probs.csv
# 2023-06-07 14:08:15,146 | INFO : Job "75825922-6c6c-47e8-8ca5-aa1965ae55f1" is starting...
# 2023-06-07 14:08:15,497 | INFO : Started compute node
# 2023-06-07 14:08:16,162 | INFO : Compute Node: Initializing
# 2023-06-07 14:08:16,556 | INFO : Job "75825922-6c6c-47e8-8ca5-aa1965ae55f1" running...
# 2023-06-07 14:08:17,711 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:08:17,714 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.60seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  7.42seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:08:26,736 | INFO : Compute Node: Computation finished
# 2023-06-07 14:08:26,737 | INFO : Compute Node: Result Ready
# 2023-06-07 14:08:27,396 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1212...
# 2023-06-07 14:08:27,397 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1212/TMRs.gff3
# 2023-06-07 14:08:27,399 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1212/plot.png
# 2023-06-07 14:08:27,400 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1212/predicted_topologies.3line
# 2023-06-07 14:08:27,401 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1212/deeptmhmm_results.md
# 2023-06-07 14:08:27,402 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1212/Type:_probs.csv
# 2023-06-07 14:08:28,746 | INFO : Job "7240e2af-4d85-4ce1-8ca7-300627c9f0fb" is starting...
# 2023-06-07 14:08:29,041 | INFO : Started compute node
# 2023-06-07 14:08:29,767 | INFO : Compute Node: Initializing
# 2023-06-07 14:08:30,276 | INFO : Job "7240e2af-4d85-4ce1-8ca7-300627c9f0fb" running...
# 2023-06-07 14:08:31,271 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:08:31,272 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  3.56seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00, 12.59seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:08:40,308 | INFO : Compute Node: Computation finished
# 2023-06-07 14:08:40,309 | INFO : Compute Node: Result Ready
# 2023-06-07 14:08:40,964 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1213...
# 2023-06-07 14:08:40,966 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1213/TMRs.gff3
# 2023-06-07 14:08:40,966 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1213/plot.png
# 2023-06-07 14:08:40,967 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1213/predicted_topologies.3line
# 2023-06-07 14:08:40,968 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1213/deeptmhmm_results.md
# 2023-06-07 14:08:40,969 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1213/Type:_probs.csv
# 2023-06-07 14:08:42,326 | INFO : Job "efd91871-94ed-4953-9b60-22f3666a2e9f" is starting...
# 2023-06-07 14:08:42,700 | INFO : Started compute node
# 2023-06-07 14:08:43,342 | INFO : Compute Node: Initializing
# 2023-06-07 14:08:43,836 | INFO : Job "efd91871-94ed-4953-9b60-22f3666a2e9f" running...
# 2023-06-07 14:08:44,846 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:08:44,847 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  1.97seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  4.79seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:08:53,912 | INFO : Compute Node: Computation finished
# 2023-06-07 14:08:53,913 | INFO : Compute Node: Result Ready
# 2023-06-07 14:08:54,528 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1214...
# 2023-06-07 14:08:54,529 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1214/TMRs.gff3
# 2023-06-07 14:08:54,530 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1214/plot.png
# 2023-06-07 14:08:54,531 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1214/predicted_topologies.3line
# 2023-06-07 14:08:54,532 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1214/deeptmhmm_results.md
# 2023-06-07 14:08:54,532 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1214/Type:_probs.csv
# 2023-06-07 14:08:55,875 | INFO : Job "aeb9fca9-02eb-4ca4-90a2-1547b4615f53" is starting...
# 2023-06-07 14:08:56,277 | INFO : Started compute node
# 2023-06-07 14:08:56,891 | INFO : Compute Node: Initializing
# 2023-06-07 14:08:57,375 | INFO : Job "aeb9fca9-02eb-4ca4-90a2-1547b4615f53" running...
# 2023-06-07 14:08:58,394 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:08:58,395 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.70seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  3.99seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:09:07,415 | INFO : Compute Node: Computation finished
# 2023-06-07 14:09:07,416 | INFO : Compute Node: Result Ready
# 2023-06-07 14:09:07,473 | ERROR : Failed to clean up <Network: 0dceec44c4bc>
# 2023-06-07 14:09:07,473 | ERROR : 404 Client Error for http+docker://localhost/v1.41/networks/0dceec44c4bc8acf091618feaea0bef45b9c74894ecfeaa5e1f54cf8a52ca692: Not Found ("network 0dceec44c4bc8acf091618feaea0bef45b9c74894ecfeaa5e1f54cf8a52ca692 not found")
# 2023-06-07 14:09:08,037 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1215...
# 2023-06-07 14:09:08,038 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1215/TMRs.gff3
# 2023-06-07 14:09:08,039 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1215/plot.png
# 2023-06-07 14:09:08,040 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1215/predicted_topologies.3line
# 2023-06-07 14:09:08,040 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1215/deeptmhmm_results.md
# 2023-06-07 14:09:08,041 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1215/Type:_probs.csv
# 2023-06-07 14:09:09,390 | INFO : Job "93050ff4-c2b3-472a-b073-726a3afb3f3e" is starting...
# 2023-06-07 14:09:09,670 | INFO : Started compute node
# 2023-06-07 14:09:10,405 | INFO : Compute Node: Initializing
# 2023-06-07 14:09:10,876 | INFO : Job "93050ff4-c2b3-472a-b073-726a3afb3f3e" running...
# 2023-06-07 14:09:11,908 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:09:11,909 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.77seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  6.33seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:09:20,934 | INFO : Compute Node: Computation finished
# 2023-06-07 14:09:20,935 | INFO : Compute Node: Result Ready
# 2023-06-07 14:09:21,565 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1216...
# 2023-06-07 14:09:21,566 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1216/TMRs.gff3
# 2023-06-07 14:09:21,567 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1216/plot.png
# 2023-06-07 14:09:21,567 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1216/predicted_topologies.3line
# 2023-06-07 14:09:21,568 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1216/deeptmhmm_results.md
# 2023-06-07 14:09:21,569 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1216/Type:_probs.csv
# 2023-06-07 14:09:22,939 | INFO : Job "084f2420-0989-41cf-bb8b-9f0699bec022" is starting...
# 2023-06-07 14:09:23,425 | INFO : Started compute node
# 2023-06-07 14:09:23,959 | INFO : Compute Node: Initializing
# 2023-06-07 14:09:24,447 | INFO : Job "084f2420-0989-41cf-bb8b-9f0699bec022" running...
# 2023-06-07 14:09:25,463 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:09:25,464 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  1.90seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  5.16seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:09:35,990 | INFO : Compute Node: Computation finished
# 2023-06-07 14:09:35,991 | INFO : Compute Node: Result Ready
# 2023-06-07 14:09:36,684 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1217...
# 2023-06-07 14:09:36,685 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1217/TMRs.gff3
# 2023-06-07 14:09:36,686 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1217/plot.png
# 2023-06-07 14:09:36,686 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1217/predicted_topologies.3line
# 2023-06-07 14:09:36,687 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1217/deeptmhmm_results.md
# 2023-06-07 14:09:36,688 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1217/Type:_probs.csv
# 2023-06-07 14:09:38,068 | INFO : Job "b19a7701-f766-4e84-8269-d49071ad6949" is starting...
# 2023-06-07 14:09:38,392 | INFO : Started compute node
# 2023-06-07 14:09:39,084 | INFO : Compute Node: Initializing
# 2023-06-07 14:09:39,597 | INFO : Job "b19a7701-f766-4e84-8269-d49071ad6949" running...
# 2023-06-07 14:09:40,588 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:09:40,588 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.07seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction:   0% 0/1 [00:00<?, ?seq/s]2023-06-07 14:09:49,611 | INFO : Compute Node: Computation finished
# Topology prediction: 100% 1/1 [00:00<00:00,  4.70seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:09:49,613 | INFO : Compute Node: Result Ready
# 2023-06-07 14:09:49,622 | ERROR : Failed to clean up <Network: 0ca9cbda88f4>
# 2023-06-07 14:09:49,622 | ERROR : 404 Client Error for http+docker://localhost/v1.41/networks/0ca9cbda88f4fec0edac1f4cf2292472fa2d2c93d52734deac741321a2d86596: Not Found ("network 0ca9cbda88f4fec0edac1f4cf2292472fa2d2c93d52734deac741321a2d86596 not found")
# 2023-06-07 14:09:50,294 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1218...
# 2023-06-07 14:09:50,295 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1218/TMRs.gff3
# 2023-06-07 14:09:50,296 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1218/plot.png
# 2023-06-07 14:09:50,297 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1218/predicted_topologies.3line
# 2023-06-07 14:09:50,298 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1218/deeptmhmm_results.md
# 2023-06-07 14:09:50,298 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1218/Type:_probs.csv
# 2023-06-07 14:09:51,642 | INFO : Job "2de269dc-24fd-4949-9c96-45692776c22c" is starting...
# 2023-06-07 14:09:51,963 | INFO : Started compute node
# 2023-06-07 14:09:52,659 | INFO : Compute Node: Initializing
# 2023-06-07 14:09:53,106 | INFO : Job "2de269dc-24fd-4949-9c96-45692776c22c" running...
# 2023-06-07 14:09:54,163 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:09:54,163 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.22seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction:   0% 0/1 [00:00<?, ?seq/s]2023-06-07 14:10:03,186 | INFO : Compute Node: Computation finished
# Topology prediction: 100% 1/1 [00:00<00:00,  4.99seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:10:03,187 | INFO : Compute Node: Result Ready
# 2023-06-07 14:10:03,194 | ERROR : Failed to clean up <Network: 72c9e9248944>
# 2023-06-07 14:10:03,195 | ERROR : 404 Client Error for http+docker://localhost/v1.41/networks/72c9e92489440c1002794bf224556bae79fff429372e8034a41dae661dce8a04: Not Found ("network 72c9e92489440c1002794bf224556bae79fff429372e8034a41dae661dce8a04 not found")
# 2023-06-07 14:10:04,408 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1219...
# 2023-06-07 14:10:04,409 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1219/TMRs.gff3
# 2023-06-07 14:10:04,410 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1219/plot.png
# 2023-06-07 14:10:04,411 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1219/predicted_topologies.3line
# 2023-06-07 14:10:04,412 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1219/deeptmhmm_results.md
# 2023-06-07 14:10:04,413 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1219/Type:_probs.csv
# 2023-06-07 14:10:05,779 | INFO : Job "c5ec0600-a1a3-4bc5-8ec8-b2c3fedb2c0b" is starting...
# 2023-06-07 14:10:06,205 | INFO : Started compute node
# 2023-06-07 14:10:06,797 | INFO : Compute Node: Initializing
# 2023-06-07 14:10:07,246 | INFO : Job "c5ec0600-a1a3-4bc5-8ec8-b2c3fedb2c0b" running...
# 2023-06-07 14:10:08,300 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:10:08,301 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.68seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  5.42seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:10:17,322 | INFO : Compute Node: Computation finished
# 2023-06-07 14:10:17,324 | INFO : Compute Node: Result Ready
# 2023-06-07 14:10:17,333 | ERROR : Failed to clean up <Network: 716d64dd9ce6>
# 2023-06-07 14:10:17,333 | ERROR : 404 Client Error for http+docker://localhost/v1.41/networks/716d64dd9ce687bad30fc0077a6ce72af0e83bbda14245be5a2c4570bd49207b: Not Found ("network 716d64dd9ce687bad30fc0077a6ce72af0e83bbda14245be5a2c4570bd49207b not found")
# 2023-06-07 14:10:17,935 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1220...
# 2023-06-07 14:10:17,936 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1220/TMRs.gff3
# 2023-06-07 14:10:17,937 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1220/plot.png
# 2023-06-07 14:10:17,938 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1220/predicted_topologies.3line
# 2023-06-07 14:10:17,938 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1220/deeptmhmm_results.md
# 2023-06-07 14:10:17,939 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1220/Type:_probs.csv
# 2023-06-07 14:10:19,310 | INFO : Job "56216d8c-0fc8-4db6-9120-8e74ae494292" is starting...
# 2023-06-07 14:10:19,737 | INFO : Started compute node
# 2023-06-07 14:10:20,327 | INFO : Compute Node: Initializing
# 2023-06-07 14:10:20,806 | INFO : Job "56216d8c-0fc8-4db6-9120-8e74ae494292" running...
# 2023-06-07 14:10:21,831 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:10:21,832 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.17seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  5.07seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:10:30,855 | INFO : Compute Node: Computation finished
# 2023-06-07 14:10:30,856 | INFO : Compute Node: Result Ready
# 2023-06-07 14:10:30,864 | ERROR : Failed to clean up <Network: 09fd2e4f0302>
# 2023-06-07 14:10:30,864 | ERROR : 404 Client Error for http+docker://localhost/v1.41/networks/09fd2e4f03025604959e569cfd27bb30d2ec56dd4b9ea9cb35687be7783444ad: Not Found ("network 09fd2e4f03025604959e569cfd27bb30d2ec56dd4b9ea9cb35687be7783444ad not found")
# 2023-06-07 14:10:31,538 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1221...
# 2023-06-07 14:10:31,539 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1221/TMRs.gff3
# 2023-06-07 14:10:31,540 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1221/plot.png
# 2023-06-07 14:10:31,541 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1221/predicted_topologies.3line
# 2023-06-07 14:10:31,542 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1221/deeptmhmm_results.md
# 2023-06-07 14:10:31,543 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1221/Type:_probs.csv
# 2023-06-07 14:10:32,897 | INFO : Job "9311f70c-d431-453e-bfb1-e2ce90da32d6" is starting...
# 2023-06-07 14:10:33,206 | INFO : Started compute node
# 2023-06-07 14:10:33,917 | INFO : Compute Node: Initializing
# 2023-06-07 14:10:34,446 | INFO : Job "9311f70c-d431-453e-bfb1-e2ce90da32d6" running...
# 2023-06-07 14:10:35,421 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:10:35,422 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.63seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  5.73seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:10:45,948 | INFO : Compute Node: Computation finished
# 2023-06-07 14:10:45,949 | INFO : Compute Node: Result Ready
# 2023-06-07 14:10:46,566 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1222...
# 2023-06-07 14:10:46,569 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1222/TMRs.gff3
# 2023-06-07 14:10:46,570 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1222/plot.png
# 2023-06-07 14:10:46,570 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1222/predicted_topologies.3line
# 2023-06-07 14:10:46,571 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1222/deeptmhmm_results.md
# 2023-06-07 14:10:46,572 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1222/Type:_probs.csv
# 2023-06-07 14:10:47,919 | INFO : Job "c2d03007-e7be-4464-84fe-ac9d1741d715" is starting...
# 2023-06-07 14:10:48,239 | INFO : Started compute node
# 2023-06-07 14:10:48,936 | INFO : Compute Node: Initializing
# 2023-06-07 14:10:49,375 | INFO : Job "c2d03007-e7be-4464-84fe-ac9d1741d715" running...
# 2023-06-07 14:10:50,439 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:10:50,440 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.63seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  7.71seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:10:59,462 | INFO : Compute Node: Computation finished
# 2023-06-07 14:10:59,463 | INFO : Compute Node: Result Ready
# 2023-06-07 14:10:59,471 | ERROR : Failed to clean up <Network: 232cca1a4b66>
# 2023-06-07 14:10:59,471 | ERROR : 404 Client Error for http+docker://localhost/v1.41/networks/232cca1a4b66cfc7995e24a423aa1ed673f65c18985d1273596bee42c9d8d967: Not Found ("network 232cca1a4b66cfc7995e24a423aa1ed673f65c18985d1273596bee42c9d8d967 not found")
# 2023-06-07 14:11:00,118 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1223...
# 2023-06-07 14:11:00,120 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1223/TMRs.gff3
# 2023-06-07 14:11:00,121 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1223/plot.png
# 2023-06-07 14:11:00,121 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1223/predicted_topologies.3line
# 2023-06-07 14:11:00,122 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1223/deeptmhmm_results.md
# 2023-06-07 14:11:00,123 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1223/Type:_probs.csv
# 2023-06-07 14:11:01,546 | INFO : Job "b9aab2e0-b304-426c-a776-4d5be3dba80e" is starting...
# 2023-06-07 14:11:01,860 | INFO : Started compute node
# 2023-06-07 14:11:02,562 | INFO : Compute Node: Initializing
# 2023-06-07 14:11:03,045 | INFO : Job "b9aab2e0-b304-426c-a776-4d5be3dba80e" running...
# 2023-06-07 14:11:04,066 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:11:04,067 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.76seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  7.16seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:11:13,090 | INFO : Compute Node: Computation finished
# 2023-06-07 14:11:13,091 | INFO : Compute Node: Result Ready
# 2023-06-07 14:11:13,098 | ERROR : Failed to clean up <Network: 728ed1f4c7c6>
# 2023-06-07 14:11:13,098 | ERROR : 404 Client Error for http+docker://localhost/v1.41/networks/728ed1f4c7c652b263fe54612ffa1761a4236323e9cb7b4789da39247931a86c: Not Found ("network 728ed1f4c7c652b263fe54612ffa1761a4236323e9cb7b4789da39247931a86c not found")
# 2023-06-07 14:11:13,715 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1224...
# 2023-06-07 14:11:13,717 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1224/TMRs.gff3
# 2023-06-07 14:11:13,718 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1224/plot.png
# 2023-06-07 14:11:13,719 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1224/predicted_topologies.3line
# 2023-06-07 14:11:13,720 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1224/deeptmhmm_results.md
# 2023-06-07 14:11:13,721 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1224/Type:_probs.csv
# 2023-06-07 14:11:15,183 | INFO : Job "d69e4ae7-efa8-4707-b4f6-8a74b7e051a6" is starting...
# 2023-06-07 14:11:15,510 | INFO : Started compute node
# 2023-06-07 14:11:16,202 | INFO : Compute Node: Initializing
# 2023-06-07 14:11:16,646 | INFO : Job "d69e4ae7-efa8-4707-b4f6-8a74b7e051a6" running...
# 2023-06-07 14:11:17,707 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:11:17,707 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.66seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  7.88seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:11:26,729 | INFO : Compute Node: Computation finished
# 2023-06-07 14:11:26,731 | INFO : Compute Node: Result Ready
# 2023-06-07 14:11:27,358 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1225...
# 2023-06-07 14:11:27,359 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1225/TMRs.gff3
# 2023-06-07 14:11:27,360 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1225/plot.png
# 2023-06-07 14:11:27,360 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1225/predicted_topologies.3line
# 2023-06-07 14:11:27,361 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1225/deeptmhmm_results.md
# 2023-06-07 14:11:27,362 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1225/Type:_probs.csv
# 2023-06-07 14:11:28,742 | INFO : Job "d9cc82b7-1d3e-4e8b-94e6-d33b02532483" is starting...
# 2023-06-07 14:11:29,123 | INFO : Started compute node
# 2023-06-07 14:11:29,758 | INFO : Compute Node: Initializing
# 2023-06-07 14:11:30,206 | INFO : Job "d9cc82b7-1d3e-4e8b-94e6-d33b02532483" running...
# 2023-06-07 14:11:31,282 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:11:31,285 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  1.74seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  6.88seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:11:41,809 | INFO : Compute Node: Computation finished
# 2023-06-07 14:11:41,809 | INFO : Compute Node: Result Ready
# 2023-06-07 14:11:42,429 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1226...
# 2023-06-07 14:11:42,430 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1226/TMRs.gff3
# 2023-06-07 14:11:42,431 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1226/plot.png
# 2023-06-07 14:11:42,432 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1226/predicted_topologies.3line
# 2023-06-07 14:11:42,432 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1226/deeptmhmm_results.md
# 2023-06-07 14:11:42,433 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1226/Type:_probs.csv
# 2023-06-07 14:11:43,796 | INFO : Job "b86b5b9f-8079-4c6a-b2f1-6ca36855de08" is starting...
# 2023-06-07 14:11:44,105 | INFO : Started compute node
# 2023-06-07 14:11:44,813 | INFO : Compute Node: Initializing
# 2023-06-07 14:11:45,327 | INFO : Job "b86b5b9f-8079-4c6a-b2f1-6ca36855de08" running...
# 2023-06-07 14:11:46,317 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:11:46,318 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.99seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  8.30seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:11:55,339 | INFO : Compute Node: Computation finished
# 2023-06-07 14:11:55,340 | INFO : Compute Node: Result Ready
# 2023-06-07 14:11:55,979 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1227...
# 2023-06-07 14:11:55,982 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1227/TMRs.gff3
# 2023-06-07 14:11:55,982 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1227/plot.png
# 2023-06-07 14:11:55,983 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1227/predicted_topologies.3line
# 2023-06-07 14:11:55,984 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1227/deeptmhmm_results.md
# 2023-06-07 14:11:55,985 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1227/Type:_probs.csv
# 2023-06-07 14:11:57,318 | INFO : Job "bddc7acc-782f-4e05-b9f9-a94b15a92778" is starting...
# 2023-06-07 14:11:57,635 | INFO : Started compute node
# 2023-06-07 14:11:58,338 | INFO : Compute Node: Initializing
# 2023-06-07 14:11:58,886 | INFO : Job "bddc7acc-782f-4e05-b9f9-a94b15a92778" running...
# 2023-06-07 14:11:59,842 | INFO : Compute Node: Pulling images...
# 2023-06-07 14:11:59,843 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.13seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction:   0% 0/1 [00:00<?, ?seq/s]2023-06-07 14:12:08,867 | INFO : Compute Node: Computation finished
# Topology prediction: 100% 1/1 [00:00<00:00,  4.87seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 14:12:08,869 | INFO : Compute Node: Result Ready
# 2023-06-07 14:12:08,878 | ERROR : Failed to clean up <Network: 8fbe157d1fc8>
# 2023-06-07 14:12:08,878 | ERROR : 404 Client Error for http+docker://localhost/v1.41/networks/8fbe157d1fc85fff23cbcebca3829114a02465780da7120a22130def9d661104: Not Found ("network 8fbe157d1fc85fff23cbcebca3829114a02465780da7120a22130def9d661104 not found")
# 2023-06-07 14:12:09,523 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1228...
# 2023-06-07 14:12:09,524 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1228/TMRs.gff3
# ...
# 2023-06-07 15:40:16,186 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1592/deeptmhmm_results.md
# 2023-06-07 15:40:16,186 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1592/Type:_probs.csv
# 2023-06-07 15:40:17,560 | INFO : Job "6e94620a-967c-4734-8cbd-bb75ddb8d575" is starting...
# 2023-06-07 15:40:17,896 | INFO : Started compute node
# 2023-06-07 15:40:18,576 | INFO : Compute Node: Initializing
# 2023-06-07 15:40:19,055 | INFO : Job "6e94620a-967c-4734-8cbd-bb75ddb8d575" running...
# 2023-06-07 15:40:20,080 | INFO : Compute Node: Pulling images...
# 2023-06-07 15:40:20,080 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  1.70seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  5.79seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 15:40:30,606 | INFO : Compute Node: Computation finished
# 2023-06-07 15:40:30,607 | INFO : Compute Node: Result Ready
# 2023-06-07 15:40:31,266 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1593...
# 2023-06-07 15:40:31,267 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1593/TMRs.gff3
# 2023-06-07 15:40:31,268 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1593/plot.png
# 2023-06-07 15:40:31,269 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1593/predicted_topologies.3line
# 2023-06-07 15:40:31,270 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1593/deeptmhmm_results.md
# 2023-06-07 15:40:31,270 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1593/Type:_probs.csv
# 2023-06-07 15:40:32,655 | INFO : Job "65105b19-66cf-45e7-b2b0-36b2f9853c87" is starting...
# 2023-06-07 15:40:32,958 | INFO : Started compute node
# 2023-06-07 15:40:33,671 | INFO : Compute Node: Initializing
# 2023-06-07 15:40:34,246 | INFO : Job "65105b19-66cf-45e7-b2b0-36b2f9853c87" running...
# 2023-06-07 15:40:35,174 | INFO : Compute Node: Pulling images...
# 2023-06-07 15:40:35,175 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  1.96seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  4.10seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 15:40:45,699 | INFO : Compute Node: Computation finished
# 2023-06-07 15:40:45,700 | INFO : Compute Node: Result Ready
# 2023-06-07 15:40:46,324 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1594...
# 2023-06-07 15:40:46,326 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1594/TMRs.gff3
# 2023-06-07 15:40:46,327 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1594/plot.png
# 2023-06-07 15:40:46,328 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1594/predicted_topologies.3line
# 2023-06-07 15:40:46,328 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1594/deeptmhmm_results.md
# 2023-06-07 15:40:46,329 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1594/Type:_probs.csv
# 2023-06-07 15:40:47,833 | INFO : Job "323db0ef-a1f6-4b90-ad22-58682df3840b" is starting...
# 2023-06-07 15:40:48,163 | INFO : Started compute node
# 2023-06-07 15:40:48,849 | INFO : Compute Node: Initializing
# 2023-06-07 15:40:49,406 | INFO : Job "323db0ef-a1f6-4b90-ad22-58682df3840b" running...
# 2023-06-07 15:40:50,352 | INFO : Compute Node: Pulling images...
# 2023-06-07 15:40:50,353 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  1.84seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  4.21seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 15:41:00,877 | INFO : Compute Node: Computation finished
# 2023-06-07 15:41:00,878 | INFO : Compute Node: Result Ready
# 2023-06-07 15:41:01,493 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1595...
# 2023-06-07 15:41:01,494 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1595/TMRs.gff3
# 2023-06-07 15:41:01,494 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1595/plot.png
# 2023-06-07 15:41:01,495 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1595/predicted_topologies.3line
# 2023-06-07 15:41:01,496 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1595/deeptmhmm_results.md
# 2023-06-07 15:41:01,496 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1595/Type:_probs.csv
# 2023-06-07 15:41:02,859 | INFO : Job "67d636ab-104c-4b81-823a-4147cecdc18c" is starting...
# 2023-06-07 15:41:03,214 | INFO : Started compute node
# 2023-06-07 15:41:03,876 | INFO : Compute Node: Initializing
# 2023-06-07 15:41:04,335 | INFO : Job "67d636ab-104c-4b81-823a-4147cecdc18c" running...
# 2023-06-07 15:41:05,379 | INFO : Compute Node: Pulling images...
# 2023-06-07 15:41:05,380 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.02seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  5.09seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 15:41:14,401 | INFO : Compute Node: Computation finished
# 2023-06-07 15:41:14,402 | INFO : Compute Node: Result Ready
# 2023-06-07 15:41:14,410 | ERROR : Failed to clean up <Network: f1750a1c0694>
# 2023-06-07 15:41:14,410 | ERROR : 404 Client Error for http+docker://localhost/v1.41/networks/f1750a1c06940cfec80e86f2296937ae3cfbea497df0f7d239e2fe5bbca08629: Not Found ("network f1750a1c06940cfec80e86f2296937ae3cfbea497df0f7d239e2fe5bbca08629 not found")
# 2023-06-07 15:41:15,057 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1596...
# 2023-06-07 15:41:15,058 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1596/TMRs.gff3
# 2023-06-07 15:41:15,058 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1596/plot.png
# 2023-06-07 15:41:15,059 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1596/predicted_topologies.3line
# 2023-06-07 15:41:15,060 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1596/deeptmhmm_results.md
# 2023-06-07 15:41:15,061 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1596/Type:_probs.csv
# 2023-06-07 15:41:16,464 | INFO : Job "19bc3e0f-1a52-4646-8a45-74c2b08e86e9" is starting...
# 2023-06-07 15:41:16,835 | INFO : Started compute node
# 2023-06-07 15:41:17,485 | INFO : Compute Node: Initializing
# 2023-06-07 15:41:18,048 | INFO : Job "19bc3e0f-1a52-4646-8a45-74c2b08e86e9" running...
# 2023-06-07 15:41:18,989 | INFO : Compute Node: Pulling images...
# 2023-06-07 15:41:18,990 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  1.69seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  4.75seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 15:41:29,519 | INFO : Compute Node: Computation finished
# 2023-06-07 15:41:29,520 | INFO : Compute Node: Result Ready
# 2023-06-07 15:41:30,179 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1597...
# 2023-06-07 15:41:30,180 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1597/TMRs.gff3
# 2023-06-07 15:41:30,181 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1597/plot.png
# 2023-06-07 15:41:30,182 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1597/predicted_topologies.3line
# 2023-06-07 15:41:30,182 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1597/deeptmhmm_results.md
# 2023-06-07 15:41:30,183 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1597/Type:_probs.csv
# 2023-06-07 15:41:31,589 | INFO : Job "fb52d85e-50a2-46bf-bb67-d4071d1462f0" is starting...
# 2023-06-07 15:41:31,948 | INFO : Started compute node
# 2023-06-07 15:41:32,607 | INFO : Compute Node: Initializing
# 2023-06-07 15:41:33,206 | INFO : Job "fb52d85e-50a2-46bf-bb67-d4071d1462f0" running...
# 2023-06-07 15:41:34,111 | INFO : Compute Node: Pulling images...
# 2023-06-07 15:41:34,112 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.45seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  4.28seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 15:41:44,637 | INFO : Compute Node: Computation finished
# 2023-06-07 15:41:44,638 | INFO : Compute Node: Result Ready
# 2023-06-07 15:41:45,271 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1598...
# 2023-06-07 15:41:45,272 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1598/TMRs.gff3
# 2023-06-07 15:41:45,273 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1598/plot.png
# 2023-06-07 15:41:45,273 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1598/predicted_topologies.3line
# 2023-06-07 15:41:45,274 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1598/deeptmhmm_results.md
# 2023-06-07 15:41:45,275 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1598/Type:_probs.csv
# 2023-06-07 15:41:46,674 | INFO : Job "0752a638-a27c-4286-9081-a77be1f6fca9" is starting...
# 2023-06-07 15:41:47,066 | INFO : Started compute node
# 2023-06-07 15:41:47,695 | INFO : Compute Node: Initializing
# 2023-06-07 15:41:48,246 | INFO : Job "0752a638-a27c-4286-9081-a77be1f6fca9" running...
# 2023-06-07 15:41:49,199 | INFO : Compute Node: Pulling images...
# 2023-06-07 15:41:49,200 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:04<00:00,  4.54s/seq]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  7.07seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 15:42:07,243 | INFO : Compute Node: Computation finished
# 2023-06-07 15:42:07,244 | INFO : Compute Node: Result Ready
# 2023-06-07 15:42:08,581 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1599...
# 2023-06-07 15:42:08,582 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1599/TMRs.gff3
# 2023-06-07 15:42:08,583 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1599/plot.png
# 2023-06-07 15:42:08,583 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1599/predicted_topologies.3line
# 2023-06-07 15:42:08,584 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1599/deeptmhmm_results.md
# 2023-06-07 15:42:08,584 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1599/Type:_probs.csv
# 2023-06-07 15:42:09,970 | INFO : Job "4e587f4c-af63-40aa-950e-1cf0af5a0e94" is starting...
# 2023-06-07 15:42:10,296 | INFO : Started compute node
# 2023-06-07 15:42:10,988 | INFO : Compute Node: Initializing
# 2023-06-07 15:42:11,456 | INFO : Job "4e587f4c-af63-40aa-950e-1cf0af5a0e94" running...
# 2023-06-07 15:42:12,491 | INFO : Compute Node: Pulling images...
# 2023-06-07 15:42:12,491 | INFO : Compute Node: Computing...
# Running DeepTMHMM on 1 sequence...
# Step 1/4 | Loading transformer model...
#
# Step 2/4 | Generating embeddings for sequences...
# Generating embeddings: 100% 1/1 [00:00<00:00,  2.08seq/s]
#
# Step 3/4 | Predicting topologies for sequences in batches of 1...
# Topology prediction: 100% 1/1 [00:00<00:00,  4.51seq/s]
#
# Step 4/4 | Generating output...
# 2023-06-07 15:42:23,020 | INFO : Compute Node: Computation finished
# 2023-06-07 15:42:23,021 | INFO : Compute Node: Result Ready
# 2023-06-07 15:42:23,659 | INFO : Saving 5 files to transmembrane_results_local_1200_1999/peptide_row1600...
# 2023-06-07 15:42:23,660 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1600/TMRs.gff3
# 2023-06-07 15:42:23,661 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1600/plot.png
# 2023-06-07 15:42:23,662 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1600/predicted_topologies.3line
# 2023-06-07 15:42:23,662 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1600/deeptmhmm_results.md
# 2023-06-07 15:42:23,663 | INFO :   - transmembrane_results_local_1200_1999/peptide_row1600/Type:_probs.csv
# 2023-06-07 15:42:25,020 | INFO : Job "0e6e49a9-8624-4f2a-9a1f-323f0ceca995" is starting...
# [2023-06-07 15:42:25 -0700] [28918] [ERROR] Connection in use: ('127.0.0.1', 43674)
# [2023-06-07 15:42:25 -0700] [28918] [ERROR] Retrying in 1 second.
# [2023-06-07 15:42:26 -0700] [28918] [ERROR] Connection in use: ('127.0.0.1', 43674)
# [2023-06-07 15:42:26 -0700] [28918] [ERROR] Retrying in 1 second.
# [2023-06-07 15:42:27 -0700] [28918] [ERROR] Connection in use: ('127.0.0.1', 43674)
# [2023-06-07 15:42:27 -0700] [28918] [ERROR] Retrying in 1 second.
# [2023-06-07 15:42:28 -0700] [28918] [ERROR] Connection in use: ('127.0.0.1', 43674)
# [2023-06-07 15:42:28 -0700] [28918] [ERROR] Retrying in 1 second.
# [2023-06-07 15:42:29 -0700] [28918] [ERROR] Connection in use: ('127.0.0.1', 43674)
# [2023-06-07 15:42:29 -0700] [28918] [ERROR] Retrying in 1 second.
# [2023-06-07 15:42:30 -0700] [28918] [ERROR] Can't connect to ('127.0.0.1', 43674)
# 2023-06-07 15:42:45,054 | ERROR : Compute failed with: Could not connect to local compute node
# ---------------------------------------------------------------------------
# BioLibError                               Traceback (most recent call last)
# Cell In[27], line 58
#      56 with biolib.Experiment('TMHMM_analysis'):
#      57     for fasta_file in fasta_list:
# ---> 58         result = deeptmhmm.cli(args='--fasta '+fasta_file, machine='local')
#      59         result.save_files(directory+'/peptide_row'+str(index))
#      60         index+=1
#
# File ~/projects/codefellows/401/DataRx-Malaria-Edition/.venv/lib/python3.11/site-packages/biolib/app/app.py:105, in BioLibApp.cli(self, args, stdin, files, override_command, machine, blocking, experiment_id, result_prefix)
#     102 except Exception as error:  # pylint: disable=broad-except
#     103     logger.debug(f'Could not update job state to failed:\n{error}')
# --> 105 raise exception
#
# File ~/projects/codefellows/401/DataRx-Malaria-Edition/.venv/lib/python3.11/site-packages/biolib/app/app.py:80, in BioLibApp.cli(self, args, stdin, files, override_command, machine, blocking, experiment_id, result_prefix)
#      77 BiolibJobApi.update_state(job['public_id'], JobState.IN_PROGRESS.value)
#      79 try:
# ---> 80     module_output = run_job(
#      81         job,
#      82         module_input_serialized,
#      83         force_local=(machine == 'local'),
#      84         result_name_prefix=result_prefix,
#      85     )
#      86     try:
#      87         BiolibJobApi.update_state(job_id=job['public_id'], state=JobState.COMPLETED.value)
#
# File ~/projects/codefellows/401/DataRx-Malaria-Edition/.venv/lib/python3.11/site-packages/biolib/app/utils.py:95, in run_job(job, module_input_serialized, force_local, result_name_prefix)
#      93     except requests.exceptions.ConnectionError:
#      94         if retry == 19:
# ---> 95             raise BioLibError('Could not connect to local compute node') from None
#      96         logger.debug('Could not connect to local compute node retrying...')
#      98 BiolibJobApi.start_local_job(job_id, module_input_serialized, node_url)
#
# BioLibError: Could not connect to local compute node
